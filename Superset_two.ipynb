# %% [markdown]
# # Superset_two problem statemnt and expected o/p :
# ![image.png](attachment:image.png)
#
# # question:
# Coding Exercise: Subsets 2
#
# Given an integer array nums that may contain duplicates, return all possible
#
# subsets
#
# (the power set).
#
# The solution set must not contain duplicate subsets. Return the solution in any order.
#
# Example :
#
# nums = [1,3,3]
#
# Output =
#
# [
#
# [],
#
# [1],
#
# [3],
#
# [1,3],
#
# [3,3],
#
# [1,3,3]
#
# ]
#
# # Superset_two problem Approach:
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#   ## Anothr example to solidify our learning for understanding this approach:
#   ![image-4.png](attachment:image-4.png)
#
# # Superset_two problem Approach [time and space complexity will be same as of approach solving for superset_one problem]:
# ### here we 're going to ignore time complexity of sorting which's O(nlogn) as its very low as compared to O(n2^n)
# ### here we're also going to ignore space taken for sorting array elements while purely focusing of space somplexity of this approach
# ![image-5.png](attachment:image-5.png)
#
# # Superset_two problem Approach [code-implementation]:
# ![image-6.png](attachment:image-6.png)

# %%
def subsetsWithDup(nums):
    res = []
    nums.sort()
    def subsets(index,curr):
        if index ==len(nums):
            res.append(curr[:])
            return
        #include
        curr.append(nums[index])
        subsets(index+1,curr)
        curr.pop()    
        #exclude
        while index<len(nums)-1 and nums[index]==nums[index+1]:
            index+=1
        subsets(index+1,curr) 
    subsets(0,[])
    return res           

nums1 = [1,3,3]
print(subsetsWithDup(nums1)) 
nums2 = [1,3,3,4,4]            
print(subsetsWithDup(nums2)) 
len(subsetsWithDup(nums2))
# Out:
# [[1, 3, 3], [1, 3], [1], [3, 3], [3], []]
# [[1, 3, 3, 4, 4], [1, 3, 3, 4], [1, 3, 3], [1, 3, 4, 4], [1, 3, 4], [1, 3], [1, 4, 4], [1, 4], [1], [3, 3, 4, 4], [3, 3, 4], [3, 3], [3, 4, 4], [3, 4], [3], [4, 4], [4], []]
# 18
