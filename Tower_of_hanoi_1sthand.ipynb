# %% [markdown]
# # tower of Hanio [problem-statement]:
# ![image.png](attachment:image.png)
#
# # tower of hanoi [expected output]:
# ![image-2.png](attachment:image-2.png)
#
# ### Coding Exercise(Tower of Hanoi)
#
# The tower of Hanoi is a famous puzzle where we have three rods and N disks. The objective of the puzzle is to move the entire stack to another rod. You are given the number of discs N. Initially, these discs are in the rod 1. You need to print all the steps of discs movement so that all the discs reach the 3rd rod. Also, you need to find the total moves.
#
#
#
# Note: The discs are arranged such that the top disc is numbered 1 and the bottom-most disc is numbered N. Also, all the discs have different sizes and a bigger disc cannot be put on the top of a smaller disc. Refer the provided link to get a better clarity about the puzzle.
#
#
#
# ### EXAMPLE:
# - For Input (N = 2)
# - Output:
# - move disk 1 from rod 1 to rod 2
# - move disk 2 from rod 1 to rod 3
# - move disk 1 from rod 2 to rod 3
# - 3

# %%
def toh(N, fromm, to, aux):
    # N is equals to number of discs we have ; whereas 'fromm' here is rod(source-rod) from where we move our disc ; 
    # and here 'to' is the rod(target-rod) to where we move our disc ; and 'aux' is here helper rod used in between 'fromm'-rod and 'to'-rod 
    #let's intitialize the moves here :

    
    # here this is helper function used to print the movement of discs in between source-target and auxilliary rods and it also return the total moves 
    def toh_helper(n, source, target, auxilliary, Moves):
        
        #base-condition 
        if n==1:  # if only one disc is the source-rod , print move like this with incresing the move by one and return simply(without further recusion)
            print(f"move disk-{n} from rod-{source} to rod-{target}")
            # and increase the moves by one here :
            Moves += 1 
            return
        
        toh_helper(n-1, source, auxilliary, target,  Moves )
        print(f"move disk-{n} from rod-{source} to rod-{target}")
        Moves += 1
        toh_helper(n-1, auxilliary, target, source, Moves )
    #let's intitialize the moves here :
    moves = 0
    toh_helper(N, fromm,to,aux,moves)
    return Moves 
    # or this will also not work:
    # return moves # as it will return simply zero value of move without increamenting the moves by one each time using recursive all 
    # as here move intialized as int zero simply and that nested fn (recusrsive-fn) can't manipulate the int value of move here out-side the recursive fn (it doesn't have scope)
    


# Example usage:
total_moves = toh(2, 1, 3, 2)
print(total_moves)    


'''
for solving the erorr :-
NameError: name 'Moves' is not defined:

Here we have to use a list for moves instead of simply initializing it as an integer (moves = 0) is due to how variable scope and mutation work in Python, 
especially within nested or recursive functions.

Explanation:
In Python, integers are immutable. This means that if you pass an integer to a function, any modifications to that integer inside the function will not affect 
the original integer outside the function. 
Each recursive call would receive its own copy of the integer, so changes made in one call would not propagate to others.

so here we will use a List for Mutation:

Lists, on the other hand, are mutable. When you pass a list to a function, the function receives a reference to the same list object. 
This means that changes made to the list (such as incrementing an element) will be reflected across all calls to the function, 
since they are all working with the same list object.
Using a list allows the move count to be updated and maintained correctly across recursive calls.
'''
# Out:
# move disk-1 from rod-1 to rod-2
# move disk-2 from rod-1 to rod-3
# move disk-1 from rod-2 to rod-3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 28
#      24     return Moves
#      27 # Example usage:
# ---> 28 total_moves = toh(2, 1, 3, 2)
#      29 print(total_moves)
#
# Cell In[12], line 24, in toh(N, fromm, to, aux)
#      22 moves = 0
#      23 toh_helper(N, fromm,to,aux,moves)
# ---> 24 return Moves
#
# NameError: name 'Moves' is not defined

# %%
def toh(N, fromm, to, aux):
    # N is equals to number of discs we have ; whereas 'fromm' here is rod(source-rod) from where we move our disc ; 
    # and here 'to' is the rod(target-rod) to where we move our disc ; and 'aux' is here helper rod used in between 'fromm'-rod and 'to'-rod 
    #let's intitialize the moves here :

    
    # here this is helper function used to print the movement of discs in between source-target and auxilliary rods and it also return the total moves 
    def toh_helper(n, source, target, auxilliary, Moves):
        #let's intitialize the moves here :
        moves = [0]
        #base-condition 
        if n==1:  # if only one disc is the source-rod , print move like this with incresing the move by one and return simply(without further recusion)
            print(f"move disk-{n} from rod-{source} to rod-{target}")
            # and increase the moves by one here :
            Moves[0] += 1 
            return
        
        toh_helper(n-1, source, auxilliary, target,  Moves )
        print(f"move disk-{n} from rod-{source} to rod-{target}")
        Moves[0] += 1
        toh_helper(n-1, auxilliary, target, source, Moves )
    #let's intitialize the moves here :
    moves = [0]
    toh_helper(N, fromm,to,aux,moves)
    return moves[0] 

# Example usage:
total_moves = toh(2, 1, 3, 2)
print(total_moves)
# Out:
# move disk-1 from rod-1 to rod-2
# move disk-2 from rod-1 to rod-3
# move disk-1 from rod-2 to rod-3
# 3

# %%
def toh(N, fromm, to, aux):
    # initializing move as zero (int) simply.
    moves = 0  
    #base-case:[only one disk to move] if n=1 ; mens if only one disc will be there and simply it will have one move [fromm--->to]
    if N == 1:
        print(f"move disk {N} from rod {fromm} to rod {to}")
        return 1 
    
     # Recursive case: move N-1 disks to auxiliary rod, move the Nth disk, then move N-1 disks to the destination rod
    moves += toh(N-1, fromm, aux, to)   # from source to auxilliary
    print(f"move disk {N} from rod {fromm} to rod {to}")
    moves +=1                        # increasing one move
    moves += toh(N-1, aux, to, fromm)  # from auxilliary to target 
    
    return moves

# Example usage :
toh(2, 1, 3, 2)   # rod-1 as source(fromm)   rod-3 as target(to)   rod-2 as Auxilliary(AUx)
    #should have 3-movement statement
# Out:
# move disk 1 from rod 1 to rod 2
# move disk 2 from rod 1 to rod 3
# move disk 1 from rod 2 to rod 3
# 3

# %%
# test cases:
print(toh(3, 1, 3, 2))  # should be 7 moves
print("====================")
print(toh(4, 1, 3, 2))
print("====================")
print(toh(5, 1, 3, 2))
# Out:
# move disk 1 from rod 1 to rod 3
# move disk 2 from rod 1 to rod 2
# move disk 1 from rod 3 to rod 2
# move disk 3 from rod 1 to rod 3
# move disk 1 from rod 2 to rod 1
# move disk 2 from rod 2 to rod 3
# move disk 1 from rod 1 to rod 3
# 7
# ...
# move disk 1 from rod 1 to rod 2
# move disk 2 from rod 1 to rod 3
# move disk 1 from rod 2 to rod 3
# move disk 3 from rod 1 to rod 2
# move disk 1 from rod 3 to rod 1
# move disk 2 from rod 3 to rod 2
# move disk 1 from rod 1 to rod 2
# move disk 4 from rod 1 to rod 3
# move disk 1 from rod 2 to rod 3
# move disk 2 from rod 2 to rod 1
# move disk 1 from rod 3 to rod 1
# move disk 3 from rod 2 to rod 3
# move disk 1 from rod 1 to rod 2
# move disk 2 from rod 1 to rod 3
# move disk 1 from rod 2 to rod 3
# 15
# ...
# move disk 1 from rod 1 to rod 3
# move disk 2 from rod 1 to rod 2
# move disk 1 from rod 3 to rod 2
# move disk 3 from rod 1 to rod 3
# move disk 1 from rod 2 to rod 1
# move disk 2 from rod 2 to rod 3
# move disk 1 from rod 1 to rod 3
# ...
